# %%
name="computer"
print(len(name))
# Out:
# 8

# %%
text="home"
print(text[-1])
# Out:
# e

# %%
text = "madam"
print(f"'{text}' is a palindrome: {is_palindrome(text)}")
# Out:
# 'madam' is a palindrome: True

# %%
text="window"
text=text.title()
print(text)
# Out:
# Window

# %%
text="apple, papaya, pineapple"
print(text.count("p"))
print(text)
# Out:
# 7
# apple, papaya, pineapple

# %%
text="pineapple"
print(text.capitalize())
# Out:
# Pineapple

# %%
text="papaya"
print(text.count("p"))
print(text.count("y"))
print(text.count("c"))
# Out:
# 2
# 1
# 0
