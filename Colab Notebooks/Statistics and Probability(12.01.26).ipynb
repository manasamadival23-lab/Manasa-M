# %%
#MEAN
import numpy as np
scores=[20,40,25,60]
print(np.mean(scores))
# Out:
# 36.25

# %%
import numpy as np
scores=[10,16,24,30]
print(np.mean(scores))
# Out:
# 20.0

# %%
#MEDIAN
import numpy as np
cricket_score=[10,12,15,100]
median_score=np.median(cricket_score)
print(f"Median:{median_score}")
# Out:
# Median:13.5

# %%
import numpy as np
quize_score=[2,18,17,19]
median_score=np.median(quize_score)
print(f"Median:{median_score}")
# Out:
# Median:17.5

# %%
#MODE
import statistics
votes=[1,2,3,2,4]
most_common=statistics.mode(votes)
print(most_common)
# Out:
# 2

# %%
import numpy as np
scores=[3,5,7,9,4,9]
print(np.mean(scores))
median_score=np.median(scores)
print(np.median(scores))
most_common=statistics.mode(scores)
print(most_common)
# Out:
# 6.166666666666667
# 6.0
# 9

# %%
#VARIENCE AND STANDARD DEVIATION
import numpy as np
tight_data=[60,70,80]
spread_data=[20,70,120]
print("tight std:",np.std(tight_data))
print("spread std:",np.std(spread_data))
# Out:
# tight std: 8.16496580927726
# spread std: 40.824829046386306

# %%
#PROBABILITY
import random
for i in range(5):
  prediction=random.choice(["spam","not spam"])
  print(f"email{i+1}:{prediction}")
# Out:
# email1:spam
# email2:spam
# email3:not spam
# email4:spam
# email5:spam

# %%
#SAMPLING AND RANDOM EXPERIMENTS
import random
samples=[random.randint(1,6)
       for _ in range(10)]
print("samples rolls:",samples)
print("samples mean:",sum(samples)/len(samples))
# Out:
# samples rolls: [5, 4, 3, 4, 1, 1, 2, 5, 2, 1]
# samples mean: 2.8
