# %%
import numpy as np
a=np.array([5,4,8,9])
b=np.array([3,7,5,2])
print(a+b)
# Out:
# [ 8 11 13 11]

# %%
x=np.array([
    [2,5],
    [3,8],
    [5,9]
    ])

# %%
np.dot([8,2,7,6],[4,9,5,2])
# Out:
# np.int64(97)

# %%
np.dot([5,3],[6,2])
# Out:
# np.int64(36)

# %%
import random
outcomes=["spam","not spam"]
print(random.choice(outcomes))
# Out:
# spam

# %%
import random
outcomes=["TRUE","FALSE"]
print(random.choice(outcomes))
# Out:
# FALSE

# %%
import numpy as np
CGPA=[8.5,8.1,9.3,8.4,7.9]
print(np.mean(CGPA))
# Out:
# 8.440000000000001

# %%
w=5
ir=0.1
for i in range(5):
  w=w-ir*2*w
  print(w)
# Out:
# 4.0
# 3.2
# 2.56
# 2.048
# 1.6384
