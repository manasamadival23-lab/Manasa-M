# %%
def function_name():
    pass

# %%
def say_hello():
    print("Hello, Welcome to Python!")

# %%
def greet(name):
    print("Hello", name)

# %%
def greet_friend(friend):
    print("Hi", friend, "! Have a great day!")

# %%
def add(a, b):
    print("Sum =", a + b)

# %%
def calculator(a, b):
    return a + b, a - b, a * b
    print(calculator(10,5))

# %%
def test():
    print("Hello")

# %%
def is_even(num):
    if num % 2 == 0:
        return "Even"
    else:
        return "Odd"
