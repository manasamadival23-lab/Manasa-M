# %%
# Traditional python list
temps_list=[72,75,68,71,74,69,73]

# %%
# Convert to numpy array
import numpy as np
temps_array=np.array([72,75,68,71,74,69,73])

# %%
print(temps_list)
print(type(temps_array))
# Out:
# [72, 75, 68, 71, 74, 69, 73]
# <class 'numpy.ndarray'>

# %%
# Temperature from 3 sensors over 5 days
season_temps=np.array([
    [72,70,71],
    [75,73,74],
    [68,67,69],
    [71,70,72],
    [74,73,72]
])
print(season_temps)
print(f"shape:{season_temps.shape}")
# Out:
# [[72 70 71]
#  [75 73 74]
#  [68 67 69]
#  [71 70 72]
#  [74 73 72]]
# shape:(5, 3)

# %%
sequence=np.arange(0,9,5)
print(sequence)
# Out:
# [0 5]

# %%
arr=np.array([[1,2,3], [4,5,6]])
print(arr.ndim)
# Out:
# 2

# %%
arr=np.array([[1,2,3], [4,5,6]])
print(arr.shape)
# Out:
# (2, 3)

# %%
arr=np.array([[1,2,3], [4,5,6]])
print(arr.size)
# Out:
# 6

# %%
arr=np.array([1,4,5,7,4,2,3])
print(arr.dtype)
# Out:
# int64

# %%
arr=np.array([1,2,3])
print(arr.itemsize)
# Out:
# 8
