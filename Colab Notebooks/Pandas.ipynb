# %%
import pandas as pd

# Crop yield data (kg per hectare)
crop_yield = pd.Series([3200, 2800, 3500, 3000],
                       index=["Wheat", "Rice", "Maize", "Millet"])

crop_yield
# Out:
# Wheat     3200
# Rice      2800
# Maize     3500
# Millet    3000
# dtype: int64

# %%
crop_yield["Rice"]
# Out:
# np.int64(2800)

# %%
crop_yield.iloc[2]
# Out:
# np.int64(3500)

# %%
crop_yield.idxmax()
# Out:
# 'Maize'

# %%
improved_yield = crop_yield * 1.05
improved_yield
# Out:
# Wheat     3360.0
# Rice      2940.0
# Maize     3675.0
# Millet    3150.0
# dtype: float64

# %%
import pandas as pd

# Crop yield data (kg per hectare)
crop_yield = pd.Series([2100, 3800, 1500, 1900],
                       index=["Wheat", "Rice", "Maize", "Millet"])

crop_yield
# Out:
# Wheat     2100
# Rice      3800
# Maize     1500
# Millet    1900
# dtype: int64

# %%
crop_yield["Rice"]
# Out:
# np.int64(3800)

# %%
crop_yield.iloc[2]
# Out:
# np.int64(1500)

# %%
crop_yield.idxmax()
# Out:
# 'Rice'

# %%
improved_yield = crop_yield * 1.05
improved_yield
# Out:
# Wheat     2205.0
# Rice      3990.0
# Maize     1575.0
# Millet    1995.0
# dtype: float64
