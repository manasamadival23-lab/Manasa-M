# %%
name="student"
age=18
print("Hello,",name)
print("You are", age,"years old.")
# Out:
# Hello, student
# You are 18 years old.

# %%
name="Manasa"
age=22
print("Hello,",name)
print("You are",age,"years old")
# Out:
# Hello, Manasa
# You are 22 years old

# %%
name= "Manasa"
age=22
print("Welcome to python,",name)
# Out:
# Welcome to python, Manasa

# %%
x=5
y=2
z=x+y*3
print(z)
# Out:
# 11

# %%
a=10
b=a-3
a=a+1
print(a,b)
# Out:
# 11 7

# %%
mark1= 70
mark2= 80
mark3= 50
total= mark1+mark2+mark3
average= total/3
print("Total=",total)
print("Average=",average)
# Out:
# Total= 200
# Average= 66.66666666666667

# %%
rows= int(input("enter number of rows:"))
for i in range(1,rows+1):
  print("*"*i)
# Out:
# enter number of rows:7
# *
# **
# ***
# ****
# *****
# ******
# *******

# %%
marks=[56,78,90,45,88]
max_mark=max(marks)
total=0
for m in marks:
  total= mapaverage=total/len(marks)
  print("max",max_mark)
  print("average",average)
# Out:
# max 90
# average 66.66666666666667
# max 90
# average 66.66666666666667
# max 90
# average 66.66666666666667
# max 90
# average 66.66666666666667
# max 90
# average 66.66666666666667

# %%
my_dictionary = {
    "apple": "a round fruit with crisp flesh and green or red skin.",
    "banana": "a long curved fruit which grows in clusters and has soft pulpy flesh and yellow skin when ripe.",
    "orange": "a round juicy citrus fruit with a tough bright reddish-yellow rind."
}

print("Dictionary created:")
print(my_dictionary)
# Out:
# Dictionary created:
# {'apple': 'a round fruit with crisp flesh and green or red skin.', 'banana': 'a long curved fruit which grows in clusters and has soft pulpy flesh and yellow skin when ripe.', 'orange': 'a round juicy citrus fruit with a tough bright reddish-yellow rind.'}

# %%
print(f"Definition of apple: {my_dictionary['apple']}")
print(f"Definition of banana: {my_dictionary.get('banana')}")
# Out:
# Definition of apple: a round fruit with crisp flesh and green or red skin.
# Definition of banana: a long curved fruit which grows in clusters and has soft pulpy flesh and yellow skin when ripe.
